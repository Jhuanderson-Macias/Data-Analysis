# %%
import os
import pandas as pd
os.getcwd()
data=pd.read_csv(os.getcwd() + '/whitehouse_waves-2015_12.csv', encoding="latin1")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#       NAMELAST NAMEFIRST NAMEMID     UIN    BDGNBR ACCESS_TYPE  \
# 0  Genachowski    Julius       M  U21456  100955.0          VA
# 1         Webb    Justin       P  U21348  100075.0          VA
# 2      SWOGGER     BRIAN       J  U19533       NaN          VA
# 3       hadley   michael       a  U21244   81750.0          VA
# 4   Stallworth     Tiara       S  U21401   95591.0          VA
#
#               TOA    POA              TOD  POD     ...      TERMINAL_SUFFIX  \
# 0  10/1/2014 6:52  A0401              NaN  NaN     ...                   CM
# 1  10/1/2014 7:21  D1102  10/1/2014 16:11  NaN     ...                   SR
# 2             NaN    NaN              NaN  NaN     ...                   CG
# 3  10/1/2014 7:24    K01   10/1/2014 9:27  NaN     ...                   RM
# 4  10/1/2014 8:03    K01   10/1/2014 8:52  NaN     ...                   BD
#
#   visitee_namelast visitee_namefirst MEETING_LOC  MEETING_ROOM  \
# ...

# %%
# Out:
# ''
